# %% [markdown]
# What is differnce between the hardware and software ? Guve one example each ?
#
# Ans:
# Hardware is physical componet of system which are CPU, GPU, Mouse, Keyboard, monitor etc....
#
# Software are designed to get desired output based on instruction we provide to computer and web based appplications, which we can not touch.
# Python, Flipcart, amazon, instagram, whatsapp etc....
